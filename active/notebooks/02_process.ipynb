# %%
import os
os.chdir(os.path.dirname(os.getcwd()) if os.path.basename(os.getcwd()) == "notebooks" else os.getcwd())

config_path = "configs/central-kalimantan.yaml"

from palmdef_risk.io.run import create_or_resume_run
ctx = create_or_resume_run(config_path, resume=True)
# Out:
# Resuming existing run: wri_central-kalimantan_baseline_20260521_112147

# %%
from palmdef_risk.process.align import align_all
align_all(ctx)
# Out:
# {'forest_t1': WindowsPath('runs/wri_central-kalimantan_baseline_20260521_112147/data/forest_t1.tif'),
#  'forest_t2': WindowsPath('runs/wri_central-kalimantan_baseline_20260521_112147/data/forest_t2.tif'),
#  'forest_t3': WindowsPath('runs/wri_central-kalimantan_baseline_20260521_112147/data/forest_t3.tif'),
#  'fcc12': WindowsPath('runs/wri_central-kalimantan_baseline_20260521_112147/data/fcc12.tif'),
#  'fcc23': WindowsPath('runs/wri_central-kalimantan_baseline_20260521_112147/data/fcc23.tif'),
#  'fcc123': WindowsPath('runs/wri_central-kalimantan_baseline_20260521_112147/data/fcc123.tif'),
#  'altitude': WindowsPath('runs/wri_central-kalimantan_baseline_20260521_112147/data/altitude.tif'),
#  'slope': WindowsPath('runs/wri_central-kalimantan_baseline_20260521_112147/data/slope.tif'),
#  'protected': WindowsPath('runs/wri_central-kalimantan_baseline_20260521_112147/data/protected.tif'),
#  'road': WindowsPath('runs/wri_central-kalimantan_baseline_20260521_112147/data/road.tif'),
#  'river': WindowsPath('runs/wri_central-kalimantan_baseline_20260521_112147/data/river.tif'),
#  'peatland': WindowsPath('runs/wri_central-kalimantan_baseline_20260521_112147/data/peatland.tif'),
#  'hgu_signed_dist': WindowsPath('runs/wri_central-kalimantan_baseline_20260521_112147/data/hgu_signed_dist.tif'),
#  'mill': WindowsPath('runs/wri_central-kalimantan_baseline_20260521_112147/data/mill.tif')}

# %%
from palmdef_risk.process.distances import compute_all_distances
compute_all_distances(ctx)

# %%
from palmdef_risk.process.gravity import compute_gravity_accessibility, compute_gravity_forecast

r2 = compute_gravity_accessibility(ctx)
print(f"Gravity R² (model)    = {r2:.3f}")

r2_fc = compute_gravity_forecast(ctx)
print(f"Gravity R² (forecast) = {r2_fc:.3f}")
# Out:
# Gravity R² (model)    = 0.023
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27552\3032653900.py in ?()
#       2
#       3 r2 = compute_gravity_accessibility(ctx)
#       4 print(f"Gravity R² (model)    = {r2:.3f}")
#       5
# ----> 6 r2_fc = compute_gravity_forecast(ctx)
#       7 print(f"Gravity R² (forecast) = {r2_fc:.3f}")
#
# g:\My Drive\JOB\WRI GDRIVE RS\Deforestation\Deforestation Risk\Technical Parts\deforestation-risk-palmoil v2.0\palmdef_risk\process\gravity.py in ?(ctx, force)
#     289     """
#     290     d = ctx.data_dir
#     291     fcast = d / "forecast"
#     292     fcast.mkdir(parents=True, exist_ok=True)
# --> 293     return _compute_gravity_for_period(
#     294         ctx,
#     295         mill_gpkg=ctx.raw_dir / "mill" / "mill_t3.gpkg",
#     296         out_raw=fcast / "gravity_raw.tif",
#
# g:\My Drive\JOB\WRI GDRIVE RS\Deforestation\Deforestation Risk\Technical Parts\deforestation-risk-palmoil v2.0\palmdef_risk\process\gravity.py in ?(ctx, mill_gpkg, out_raw, out_resid, dist_road, dist_town, force)
#     224             )
#     225             out_raw.unlink()
#     226             if out_resid.exists():
#     227                 out_resid.unlink()
# --> 228         elif _is_zero_raster(out_raw):
#     229             logger.warning(
#     230                 "%s max≈0 (mill CRS mismatch in prior run) — recomputing",
#     231                 out_raw.name,
#
# g:\My Drive\JOB\WRI GDRIVE RS\Deforestation\Deforestation Risk\Technical Parts\deforestation-risk-palmoil v2.0\palmdef_risk\process\gravity.py in ?(path)
#     186     """Return True if raster max ≈ 0 (mill burn failed — CRS mismatch)."""
#     187     ds = gdal.Open(str(path))
#     188     if ds is None:
#     189         return True
# --> 190     stats = ds.GetRasterBand(1).GetStatistics(0, 1)
#     191     ds = None
#     192     return stats[1] < 1e-6
#
# c:\Users\musli\.conda\envs\conda-far\Lib\site-packages\osgeo\gdal.py in ?(self, *args)
#    9292         :py:meth:`GetMinimum`
#    9293         :py:meth:`GetStatistics`
#    9294
#    9295         """
# -> 9296         return _gdal.Band_GetStatistics(self, *args)
#
# RuntimeError: gravity_raw.tif, band 1: IReadBlock failed at X offset 4, Y offset 19: TIFFReadEncodedTile() failed.
# May be caused by: TIFFReadEncodedTile() failed.
# May be caused by: TIFFFillTile:Read error at row 768, col 12288, tile 1391; got 0 bytes, expected 271248

# %%
from palmdef_risk.process.align import compute_hgu_signed_distance
compute_hgu_signed_distance(
    str(ctx.raw_dir / "user_inputs" / "hgu.gpkg"),
    str(ctx.data_dir / "forest_t2.tif"),
    str(ctx.data_dir / "hgu_signed_dist.tif"),
)
